# %%
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,1,2,3,5])
y=[2,5,7,9,10]
plt.scatter(x,y,color='red',marker='+')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price)
plt.xlabel("Area(sq)")
plt.ylabel("price(us$)")
plt.plot(df['area'],reg.predict(df[['area']]),color='red')
#draw the linear model

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
a=reg.predict([[1000]])
a[0]
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 316404.1095890411

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
df=pd.read_csv('areas.csv')
df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
def getPrice(x):
    res=reg.predict([[x]])
    return res[0]
a=getPrice(3333)
a


df['prices']=df['area'].apply(lambda x:getPrice(x))
df
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
reg.predict(df)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
p=reg.predict(df)
df['prices']=p
df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df.to_csv('prediction.csv',index=False)
#generate new prediction file

# %%
reg.predict([[5000]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
import pickle
f=open('model_pickle','wb')
pickle.dump(reg,f)

# %%
fa=open('model_pickle','rb')
mymodel=pickle.load(fa)

# %%
mymodel.predict([[5000]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
mymodel.coef_
# Out:
# array([135.78767123])

# %%
mymodel.intercept_
# Out:
# 180616.43835616432

# %%
import joblib

# %%
joblib.dump(reg,'model_joblibsaved')
# Out:
# ['model_joblibsaved']

# %%
mymodel2=joblib.load('model_joblibsaved')

# %%
mymodel2.predict([[5000]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
