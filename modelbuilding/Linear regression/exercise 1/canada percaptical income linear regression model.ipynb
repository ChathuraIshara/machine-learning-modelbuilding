# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('canada_per_capita_income.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.scatter(df['year'],df['per capita income (US$)'])
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.plot(df['year'],reg.predict(df[['year']]),color='red')  #drew the linear regression line on the scatter plot
#generated the scatter plot of data set for identifing whether there is a linear relationship between variables

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
#trained the linear regression model
# Out:
# LinearRegression()

# %%
res=reg.predict([[2023]])
print("Predicted per capita income (US$) in 2023",res[0],"$")
#calculated the per capita income (US$) in 2023
# Out:
# Predicted per capita income (US$) in 2023 43774.08932008571 $
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_row_data={'year':2023,'per capita income (US$)':res[0]}
df=df.append(new_row_data,ignore_index=True)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13092\1267414622.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(new_row_data,ignore_index=True)
#       year  per capita income (US$)
# 0   1970.0              3399.299037
# 1   1971.0              3768.297935
# 2   1972.0              4251.175484
# 3   1973.0              4804.463248
# 4   1974.0              5576.514583
# 5   1975.0              5998.144346
# 6   1976.0              7062.131392
# 7   1977.0              7100.126170
# 8   1978.0              7247.967035
# 9   1979.0              7602.912681
# 10  1980.0              8355.968120
# 11  1981.0              9434.390652
# 12  1982.0              9619.438377
# 13  1983.0             10416.536590
# 14  1984.0             10790.328720
# 15  1985.0             11018.955850
# 16  1986.0             11482.891530
# 17  1987.0             12974.806620
# ...

# %%
df.to_csv('canada_per_capita_income.csv',index=False)
