# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df['Rzscore']=(df['RestingBP']-df.RestingBP.mean())/(df.RestingBP.std())
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore
# ...

# %%
df['Czscore']=(df['Cholesterol']-df.Cholesterol.mean())/(df.Cholesterol.std())
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore
# ...

# %%
df['Mzscore']=(df['MaxHR']-df.MaxHR.mean())/(df.MaxHR.std())
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore  \
# ...

# %%
df['Ozscore']=(df['Oldpeak']-df.Oldpeak.mean())/(df.Oldpeak.std())
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore  \
# ...

# %%
dfnooutliers=df[(((df.Rzscore>-3) & (df.Rzscore<3)) & ((df.Czscore>-3) & (df.Czscore<3)) & ((df.Mzscore>-3) & (df.Mzscore<3)) & ((df.Mzscore>-3) & (df.Mzscore<3)))]
#removing outliers

# %%
dfnooutliers.shape
# Out:
# (906, 16)

# %%
newdf=dfnooutliers.drop(['Rzscore','Czscore','Mzscore','Ozscore'],axis='columns')
newdf
#removing zscore columns
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
dfwithouttext=pd.get_dummies(newdf,drop_first=True)
dfwithouttext #converting text data to numeric using one hot encoding
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
x=dfwithouttext.drop(['HeartDisease'],axis='columns')
y=dfwithouttext.HeartDisease
scaler=StandardScaler()
xscaled=scaler.fit_transform(x,y)
xscaled
# Out:
# array([[-1.43268734,  0.46074981,  0.848846  , ..., -0.8232726 ,
#         -0.99779493,  1.14251631],
#        [-0.47787471,  1.62434375, -0.16934854, ..., -0.8232726 ,
#          1.00220995, -0.87526103],
#        [-1.75095822, -0.12104716,  0.79279859, ..., -0.8232726 ,
#         -0.99779493,  1.14251631],
#        ...,
#        [ 0.37084763, -0.12104716, -0.62706901, ...,  1.2146645 ,
#          1.00220995, -0.87526103],
#        [ 0.37084763, -0.12104716,  0.35376058, ..., -0.8232726 ,
#          1.00220995, -0.87526103],
#        [-1.64486793,  0.34439041, -0.21605471, ..., -0.8232726 ,
#         -0.99779493,  1.14251631]])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xscaled,y,test_size=0.2)
model=SVC()
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model.score(xtest,ytest)
# Out:
# 0.8846153846153846

# %%
bagmodel=BaggingClassifier(
        base_estimator=SVC(),
        n_estimators=100,
        max_samples=0.8,
        oob_score=True,
        random_state=0
)
bagmodel.fit(xtrain,ytrain)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=SVC(), max_samples=0.8, n_estimators=100,
#                   oob_score=True, random_state=0)

# %%
bagmodel.oob_score_
# Out:
# 0.8674033149171271

# %%
bagmodel.score(xtest,ytest)##bag model with standalone support vectore machine
# Out:
# 0.8846153846153846

# %%
scores=cross_val_score(SVC(),x,y,cv=5)
scores.mean()
# Out:
# 0.6899034666990468

# %%
bagmodel=BaggingClassifier(
        base_estimator=SVC(),
        n_estimators=100,
        max_samples=0.8,
        oob_score=True,
        random_state=0
)
scores=cross_val_score(bagmodel,x,y,cv=5)
scores.mean()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
scores=cross_val_score(DecisionTreeClassifier(),x,y,cv=5)
scores.mean()
# Out:
# 0.7361483820047356

# %%
bagmodel=BaggingClassifier(
        base_estimator=DecisionTreeClassifier(),
        n_estimators=100,
        max_samples=0.8,
        oob_score=True,
        random_state=0  #bagging with Decision tree classifer.here bagging gives more score level than standalone  decesion tree
)
scores=cross_val_score(bagmodel,x,y,cv=5)
scores.mean()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...
