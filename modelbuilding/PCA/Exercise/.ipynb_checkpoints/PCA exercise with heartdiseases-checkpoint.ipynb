# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df['Rzscore']=(df.RestingBP-df.RestingBP.mean())/(df.RestingBP.std())
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore
# 0              N      0.0       Up             0  0.410685
# 1              N      1.0     Flat             1  1.490940
# 2              N      0.0       Up             0 -0.129442
# 3              Y      1.5     Flat             1  0.302660
# 4              N      0.0       Up             0  0.950812

# %%
df['Czscore']=(df.Cholesterol-df.Cholesterol.mean())/(df.Cholesterol.std())
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore
# 0              N      0.0       Up             0  0.410685  0.824621
# 1              N      1.0     Flat             1  1.490940 -0.171867
# 2              N      0.0       Up             0 -0.129442  0.769768
# 3              Y      1.5     Flat             1  0.302660  0.138964
# 4              N      0.0       Up             0  0.950812 -0.034736

# %%
df['Mzscore']=(df.MaxHR-df.MaxHR.mean())/(df.MaxHR.std())
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore   Mzscore
# 0              N      0.0       Up             0  0.410685  0.824621  1.382175
# 1              N      1.0     Flat             1  1.490940 -0.171867  0.753746
# 2              N      0.0       Up             0 -0.129442  0.769768 -1.524307
# 3              Y      1.5     Flat             1  0.302660  0.138964 -1.131539
# 4              N      0.0       Up             0  0.950812 -0.034736 -0.581664

# %%
df['Ozscore']=(df.Oldpeak-df.Oldpeak.mean())/(df.Oldpeak.std())
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore  \
# 0              N      0.0       Up             0  0.410685  0.824621
# 1              N      1.0     Flat             1  1.490940 -0.171867
# 2              N      0.0       Up             0 -0.129442  0.769768
# 3              Y      1.5     Flat             1  0.302660  0.138964
# 4              N      0.0       Up             0  0.950812 -0.034736
#
#     Mzscore   Ozscore
# 0  1.382175 -0.831979
# 1  0.753746  0.105606
# 2 -1.524307 -0.831979
# 3 -1.131539  0.574398
# 4 -0.581664 -0.831979

# %%
dfnooutliers=df[(((df.Rzscore<3) & (df.Rzscore>-3)) & ((df.Czscore<3) & (df.Czscore>-3)) & ((df.Mzscore<3) & (df.Mzscore>-3)) & ((df.Ozscore<3) & (df.Ozscore>-3)))]
dfnooutliers
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   Rzscore   Czscore  \
# 0      172              N      0.0       Up             0  0.410685  0.824621
# 1      156              N      1.0     Flat             1  1.490940 -0.171867
# 2       98              N      0.0       Up             0 -0.129442  0.769768
# 3      108              Y      1.5     Flat             1  0.302660  0.138964
# 4      122              N      0.0       Up             0  0.950812 -0.034736
# ..     ...            ...      ...      ...           ...       ...       ...
# 913    132              N      1.2     Flat             1 -1.209697  0.596068
# 914    141              N      3.4     Flat             1  0.626736 -0.053020
# 915    115              Y      1.2     Flat             1 -0.129442 -0.619830
# 916    174              N      0.0     Flat             1 -0.129442  0.340090
# 917    173              N      0.0       Up             0  0.302660 -0.217578
#
#       Mzscore   Ozscore
# 0    1.382175 -0.831979
# 1    0.753746  0.105606
# 2   -1.524307 -0.831979
# 3   -1.131539  0.574398
# 4   -0.581664 -0.831979
# ..        ...       ...
# 913 -0.188897  0.293123
# 914  0.164595  2.355810
# 915 -0.856602  0.293123
# 916  1.460728 -0.831979
# 917  1.421452 -0.831979
#
# [899 rows x 16 columns]

# %%
df.shape
# Out:
# (918, 16)

# %%
dfnooutliers.shape
# Out:
# (899, 16)

# %%
newdf=dfnooutliers.drop(['Rzscore','Czscore','Mzscore','Ozscore'],axis='columns')

# %%
newdf
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [899 rows x 12 columns]

# %%
dfafterencoding=pd.get_dummies(newdf,drop_first=True)
dfafterencoding
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0        1                  1                  0                 0
# 1        0                  0                  1                 0
# 2        1                  1                  0                 0
# 3        0                  0                  0                 0
# 4        1                  0                  1                 0
# ..     ...                ...                ...               ...
# 913      1                  0                  0                 1
# 914      1                  0                  0                 0
# 915      1                  0                  0                 0
# 916      0                  1                  0                 0
# 917      1                  0                  1                 0
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                    1              0                 0              0
# 1                    1              0                 0              1
# 2                    0              1                 0              0
# 3                    1              0                 1              1
# 4                    1              0                 0              0
# ..                 ...            ...               ...            ...
# 913                  1              0                 0              1
# 914                  1              0                 0              1
# 915                  1              0                 1              1
# 916                  0              0                 0              1
# 917                  1              0                 0              0
#
#      ST_Slope_Up
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ..           ...
# 913            0
# 914            0
# 915            0
# 916            0
# 917            1
#
# [899 rows x 16 columns]

# %%
x=dfafterencoding.drop(['HeartDisease'],axis='columns')
scl=StandardScaler()
xscaled=scl.fit_transform(x)
y=dfafterencoding.HeartDisease

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xscaled,y,test_size=0.2)
len(xtrain)
# Out:
# 719

# %%
model_params={
    'svm':
    {
        'model':SVC(),
        'params':{
            'C':[1,10,20],
            'kernel':['linear','rbf']
        }
    },
    'randomforest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10]
        }
    },
    'logisticregression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'C':[1,5,10]
        }
    }
}

# %%
scores=[]
for modelname,mp in model_params.items():
    clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    clf.fit(x,y)
    scores.append({
        'model':model_name,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })

# %%
df
